# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = df.iloc[:,0:1]

# %%
y = df.iloc[:,1:2]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 44)

# %%
from sklearn.linear_model import LinearRegression

# %%
X_train
# Out:
#      cgpa
# 138  7.91
# 46   6.07
# 118  7.40
# 85   4.79
# 110  8.18
# ..    ...
# 131  6.37
# 59   7.56
# 173  6.75
# 163  8.93
# 20   7.28
#
# [160 rows x 1 columns]

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear_model.predict(X_test)

# %%
y_pred
# Out:
# array([[2.47436129],
#        [3.82210977],
#        [2.68746682],
#        [2.38220755],
#        [2.52619777],
#        [3.09639905],
#        [2.91209157],
#        [3.23462966],
#        [2.32461146],
#        [2.45132286],
#        [2.52619777],
#        [2.08270789],
#        [2.3476499 ],
#        [3.20007201],
#        [3.74723485],
#        [3.31526419],
#        [2.91785118],
#        [3.49381206],
#        [2.65866878],
#        [2.32461146],
#        [3.04456257],
#        [2.36492873],
#        [2.95240883],
#        [2.84873587],
#        [4.11009021],
#        [2.96968766],
#        [3.69539837],
#        [2.20941929],
#        [2.79689939],
#        [3.65508111],
#        [3.93154233],
#        [2.52619777],
#        [3.90274429],
#        [2.47436129],
#        [2.77962056],
#        [3.37286028],
#        [2.38796716],
#        [2.56651504],
#        [2.76810135],
#        [3.33830262]])

# %%
from sklearn.metrics import accuracy_score, r2_score

# %%
y_test
# Out:
#      package
# 135     2.60
# 73      4.03
# 157     2.70
# 28      2.24
# 23      2.48
# 79      3.00
# 54      3.09
# 3       3.67
# 114     1.87
# 124     2.31
# 180     2.72
# 111     2.25
# 182     2.08
# 64      2.92
# 9       3.51
# 68      2.99
# 35      2.87
# 45      3.58
# 89      2.72
# 47      3.26
# 177     3.64
# 126     2.60
# 142     3.04
# 7       2.48
# 12      3.65
# 32      3.08
# 181     3.89
# 136     2.10
# 105     2.82
# 178     3.63
# 48      4.09
# 190     2.69
# 112     4.10
# 81      2.20
# 95      2.79
# 43      2.76
# 158     3.04
# 187     2.44
# 99      3.24
# 65      3.81

# %%
X_test
# Out:
#      cgpa
# 135  6.10
# 73   8.44
# 157  6.47
# 28   5.94
# 23   6.19
# 79   7.18
# 54   6.86
# 3    7.42
# 114  5.84
# 124  6.06
# 180  6.19
# 111  5.42
# 182  5.88
# 64   7.36
# 9    8.31
# 68   7.56
# 35   6.87
# 45   7.87
# 89   6.42
# 47   5.84
# 177  7.09
# 126  5.91
# 142  6.93
# 7    6.75
# 12   8.94
# 32   6.96
# 181  8.22
# 136  5.64
# 105  6.66
# 178  8.15
# 48   8.63
# 190  6.19
# 112  8.58
# 81   6.10
# 95   6.63
# 43   7.66
# 158  5.95
# 187  6.26
# 99   6.61
# 65   7.60

# %%
# y_pred = np.where(y_pred > 0, 1, 0)

# %%
y_pred
# Out:
# array([[2.47436129],
#        [3.82210977],
#        [2.68746682],
#        [2.38220755],
#        [2.52619777],
#        [3.09639905],
#        [2.91209157],
#        [3.23462966],
#        [2.32461146],
#        [2.45132286],
#        [2.52619777],
#        [2.08270789],
#        [2.3476499 ],
#        [3.20007201],
#        [3.74723485],
#        [3.31526419],
#        [2.91785118],
#        [3.49381206],
#        [2.65866878],
#        [2.32461146],
#        [3.04456257],
#        [2.36492873],
#        [2.95240883],
#        [2.84873587],
#        [4.11009021],
#        [2.96968766],
#        [3.69539837],
#        [2.20941929],
#        [2.79689939],
#        [3.65508111],
#        [3.93154233],
#        [2.52619777],
#        [3.90274429],
#        [2.47436129],
#        [2.77962056],
#        [3.37286028],
#        [2.38796716],
#        [2.56651504],
#        [2.76810135],
#        [3.33830262]])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7132448670858387

# %%
import pickle

# %%
with open('model.pkl', 'wb') as file:
    pickle.dump(linear_model, file)

# %%
with open('model.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
prediction = model.predict([[9.0]])  # Provide only the features used for training
print(prediction)
# Out:
# [[4.14464786]]
# C:\Users\manit\anaconda3\envs\ml\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
